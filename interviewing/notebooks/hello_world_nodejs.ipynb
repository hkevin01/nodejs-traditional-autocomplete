# %% [markdown]
# # 👋 Hello World - Node.js\n\nSimple Node.js demonstrations with **traditional autocomplete**.

# %%
import subprocess\n\ncode = "console.log(\"Hello World! 🌍\"); console.log(\"Node version:\", process.version);"\nresult = subprocess.run(["node", "-e", code], capture_output=True, text=True)\nprint(result.stdout)
